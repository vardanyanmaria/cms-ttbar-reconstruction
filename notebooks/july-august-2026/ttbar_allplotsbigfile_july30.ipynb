# %%
import ROOT as r
import math
import numpy as np
from itertools import combinations
from neutrinosolver import *
from collections import Counter

# opens file and tree
f = r.TFile("actual_data/RunIISummer20UL17NanoAODv9-2_TTtoLNu2Q-1Jets-smeft_MTT-0to700_TuneCP5_13TeV_madgraphMLM-pythia8-2_NANOAODSIM106X_mc2017.root")
tree = f.Get("Events")

nEvents = tree.GetEntries()

print("Events in file:", nEvents)

# classes for muon, electron, jets

class MyMuon(r.TLorentzVector):
    def __init__(self, pt=0, eta=0, phi=0, mass=0, iso=0.0, charge=0):
        super().__init__()
        self.SetPtEtaPhiM(pt, eta, phi, mass)
        self.isolation = iso
        self.charge = charge
    
    
    def IsIsolated(self, relcut=0.1):
        if self.Pt() == 0:
            return False
        return self.isolation < relcut

class MyElectron(r.TLorentzVector):
    def __init__(self, pt=0, eta=0, phi=0, mass=0, iso=0.0, charge=0, cutBased=0):
        super().__init__()
        self.SetPtEtaPhiM(pt, eta, phi, mass)
        self.isolation = iso
        self.charge = charge
        self.cutBased = cutBased

    def IsIsolated(self, relcut=0.1):
        if self.Pt() == 0:
            return False
        return self.isolation < relcut

class MyJet(r.TLorentzVector):
    def __init__(self, pt=0, eta=0, phi=0, mass=0, btag=0.0, jetid=False):
        super().__init__()
        self.SetPtEtaPhiM(pt, eta, phi, mass)
        self.btag = btag
        self.jetid = jetid
        self.is_btagged = False

    def IsBTagged(self, threshold):
        return self.btag > threshold

    def HasJetID(self):
        return (self.jetid & 2) != 0
    
    

# histograms

h_Mwh_vs_Mth = r.TH2F(
    "h_Mwh_vs_Mth",
    "M(W_h) vs M(t_h); M(t_h) [GeV]; M(W_h) [GeV]",
    100, 0, 500,   # 5 GeV x bins
    60, 0, 300     # 5 GeV y bins
)

# Dn,min distributions
h_Dn_correct = r.TH1F(
    "h_Dn_correct",
    "Correct leptonic b;D_{n,min};Normalized events",
    50, 0, 150
)

h_Dn_wrong = r.TH1F(
    "h_Dn_wrong",
    "Wrong leptonic b;D_{n,min};Normalized events",
    50, 0, 150
)

# Hadronic b candidate distributions
h_Dn_bh_correct = r.TH1F(
    "h_Dn_bh_correct",
    "Correct hadronic b;D_{n,min};Normalized events",
    50, 0, 150
)

h_Dn_bh_wrong = r.TH1F(
    "h_Dn_bh_wrong",
    "Wrong hadronic b;D_{n,min};Normalized events",
    50, 0, 150
)

# bh + light jet mass
h_Mbhj_correct = r.TH1F(
    "h_Mbhj_correct",
    "Correct bh+jet;M(b_{h}+j) [GeV];Normalized events",
    50, 0, 500
)

h_Mbhj_wrong = r.TH1F(
    "h_Mbhj_wrong",
    "Wrong bh+jet;M(b_{h}+j) [GeV];Normalized events",
    50, 0, 500
)


# weighted error
h_Mwh_vs_Mth.Sumw2()

h_Dn_correct.Sumw2()
h_Dn_wrong.Sumw2()

h_Dn_bh_correct.Sumw2()
h_Dn_bh_wrong.Sumw2()

h_Mbhj_correct.Sumw2()
h_Mbhj_wrong.Sumw2()


# analysis cuts

cuts = {
    "Muon": {
        "pt_min": 30.0,
        "eta_max": 2.4,
        "iso_max": 0.15
    },
    "Electron": {
        "pt_min": 30.0,
        "eta_max": 2.4,
        "cutBased": 4,
        "iso_max": 0.15
        
    },
    "Jets": {
        "pt_min": 30.0,
        "eta_max": 2.4,
        "btag": 0.3040
    },
    "MET": {
        "pt_min": 20.0
    }
}

cuts["Trigger"] = {
    "muon": ["HLT_IsoMu27"],
    "electron": ["HLT_Ele27_WPTight_Gsf", "HLT_Ele32_WPTight_Gsf"]
}

cutflow = {
    "total": 0,

    # triggers
    "pass_mu_trigger": 0,
    "pass_ele_trigger": 0,

    # lepton selection
    "exactly_1_lepton": 0,

    # MET
    "pass_MET": 0,

    # jets
    "3jets": 0,
    "4plus_jets": 0,

    # b-tag categories
    "4pj_2b": 0,
    "4pj_1b": 0,
    "3j_2b": 0,
}

def make_gen_vector(idx):
    vec = r.TLorentzVector()
    vec.SetPtEtaPhiM(
        tree.GenPart_pt[idx],
        tree.GenPart_eta[idx],
        tree.GenPart_phi[idx],
        tree.GenPart_mass[idx]
    )
    return vec



def make_neutrino(nusol):
    nu_vec = nusol.nu

    nu = r.TLorentzVector()
    nu.SetPxPyPzE(
        nu_vec[0],
        nu_vec[1],
        nu_vec[2],
        math.sqrt(
            nu_vec[0]**2 +
            nu_vec[1]**2 +
            nu_vec[2]**2
        )
    )

    return nu

LAST_COPY_BIT = 13


def get_children(parent_idx, mothers):
    """Return indices whose direct mother is parent_idx."""
    return [
        idx for idx, mother_idx in enumerate(mothers)
        if mother_idx == parent_idx
    ]


def get_mother_pdg(idx, mothers, pdg_ids):
    """
    GenPart_genPartIdxMother contains an INDEX, not a PDG ID.
    This function converts that mother index into its PDG ID.
    """
    mother_idx = mothers[idx]

    if mother_idx < 0 or mother_idx >= len(pdg_ids):
        return None

    return pdg_ids[mother_idx]


def is_last_copy(idx):
    """Check the NanoAOD isLastCopy status flag."""
    flags = int(tree.GenPart_statusFlags[idx])
    return bool(flags & (1 << LAST_COPY_BIT))


def get_copy_chain(idx, mothers, pdg_ids):
    """
    Follow a particle through children with exactly the same PDG ID.
    """
    chain = [idx]
    visited = {idx}

    while True:
        current = chain[-1]

        same_pdg_children = [
            child_idx
            for child_idx in get_children(current, mothers)
            if pdg_ids[child_idx] == pdg_ids[current]
            and child_idx not in visited
        ]

        if len(same_pdg_children) == 0:
            break

        if len(same_pdg_children) > 1:
            print(
                "WARNING: multiple same-PDG children:",
                "parent =", current,
                "pdg =", pdg_ids[current],
                "children =", same_pdg_children
            )

        current = same_pdg_children[0]
        chain.append(current)
        visited.add(current)

    return chain


def get_last_copy(idx, mothers, pdg_ids):
    return get_copy_chain(idx, mothers, pdg_ids)[-1]


def get_decay_products(idx, mothers, pdg_ids):
    chain = get_copy_chain(idx, mothers, pdg_ids)
    chain_set = set(chain)

    products = []

    for parent_idx in chain:
        for child_idx in get_children(parent_idx, mothers):
            if child_idx not in chain_set:
                products.append(child_idx)

    # Remove duplicates while preserving order
    return list(dict.fromkeys(products))


def classify_w_decay(W_idx, mothers, pdg_ids):
    #check if w decay is lep or had
    W_idx = get_last_copy(W_idx, mothers, pdg_ids)
    W_pdg = pdg_ids[W_idx]

    if W_pdg not in (24, -24):
        return None, []

    daughters = get_decay_products(W_idx, mothers, pdg_ids)

    if W_pdg == 24:
        allowed_leptons = {-11, -13, -15}
        allowed_neutrinos = {12, 14, 16}

        allowed_up_quarks = {2, 4}
        allowed_down_quarks = {-1, -3, -5}

    else:
        allowed_leptons = {11, 13, 15}
        allowed_neutrinos = {-12, -14, -16}

        allowed_up_quarks = {-2, -4}
        allowed_down_quarks = {1, 3, 5}

    leptons = [
        idx for idx in daughters
        if pdg_ids[idx] in allowed_leptons
    ]

    neutrinos = [
        idx for idx in daughters
        if pdg_ids[idx] in allowed_neutrinos
    ]

    # Check that the lepton and neutrino have the same flavor
    for lepton_idx in leptons:
        for neutrino_idx in neutrinos:
            if abs(pdg_ids[neutrino_idx]) == abs(pdg_ids[lepton_idx]) + 1:
                return "leptonic", [lepton_idx, neutrino_idx]

    quarks = [
        idx for idx in daughters
        if 1 <= abs(pdg_ids[idx]) <= 5
    ]

    # Check the allowed W quark charges/signs
    for q1_idx, q2_idx in combinations(quarks, 2):
        q1_pdg = pdg_ids[q1_idx]
        q2_pdg = pdg_ids[q2_idx]

        valid_pair = (
            q1_pdg in allowed_up_quarks
            and q2_pdg in allowed_down_quarks
        ) or (
            q2_pdg in allowed_up_quarks
            and q1_pdg in allowed_down_quarks
        )

        if valid_pair:
            q1_last = get_last_copy(q1_idx, mothers, pdg_ids)
            q2_last = get_last_copy(q2_idx, mothers, pdg_ids)

            return "hadronic", [q1_last, q2_last]

    return None, []


def print_gen_table(event, mothers, pdg_ids):
    #to crosscheck
    print(f"\n========== GENERATOR EVENT {event} ==========")

    for idx, pdg_id in enumerate(pdg_ids):
        mother_idx = mothers[idx]
        mother_pdg = get_mother_pdg(idx, mothers, pdg_ids)

        print(
            f"idx={idx:3d}  "
            f"pdg={pdg_id:5d}  "
            f"mother_idx={mother_idx:3d}  "
            f"mother_pdg={str(mother_pdg):>5s}  "
            f"lastCopy={is_last_copy(idx)}"
        )

n_3jet_before_solver = 0
n_3jet_solver_success = 0
n_3jet_solver_fail = 0

truth_fail = Counter()

# Print the full generator table for only the first two events.
# to crosscheck
DEBUG_GEN_EVENTS = 2

# event loop
for event in range(nEvents):

    cutflow["total"] += 1

    tree.GetEntry(event)
    weight = tree.Generator_weight

    gen_b_had = None
    gen_b_lep = None
    gen_w_quarks = []

    gen_b_had_idx = None
    gen_b_lep_idx = None
    gen_w_quark_idxs = []

    # These are integer indices and integer PDG IDs.
    gen_mothers = [
        int(value)
        for value in tree.GenPart_genPartIdxMother
    ]

    gen_pdg_ids = [
        int(value)
        for value in tree.GenPart_pdgId
    ]

    # Print index, PDG ID, mother index and mother PDG ID.
    if event < DEBUG_GEN_EVENTS:
        print_gen_table(event, gen_mothers, gen_pdg_ids)

    # Explicitly find the last-copy top and antitop.
    top_candidates = [
        idx for idx in range(tree.nGenPart)
        if gen_pdg_ids[idx] == 6
        and is_last_copy(idx)
    ]

    antitop_candidates = [
        idx for idx in range(tree.nGenPart)
        if gen_pdg_ids[idx] == -6
        and is_last_copy(idx)
    ]

    if len(top_candidates) != 1:
        truth_fail["not_exactly_one_last_copy_top"] += 1
        continue

    if len(antitop_candidates) != 1:
        truth_fail["not_exactly_one_last_copy_antitop"] += 1
        continue

    top_idx = top_candidates[0]
    antitop_idx = antitop_candidates[0]

    # Final safety check that these really are t and anti-t.
    if gen_pdg_ids[top_idx] != 6:
        truth_fail["selected_top_has_wrong_pdg"] += 1
        continue

    if gen_pdg_ids[antitop_idx] != -6:
        truth_fail["selected_antitop_has_wrong_pdg"] += 1
        continue

    truth_event_valid = True

    for current_top_idx in (top_idx, antitop_idx):

        current_top_pdg = gen_pdg_ids[current_top_idx]

        # Explicit charge-consistent top decay:
        #
        # t     -> W+ b
        # anti-t -> W- anti-b
        if current_top_pdg == 6:
            expected_W_pdg = 24
            expected_b_pdg = 5

        elif current_top_pdg == -6:
            expected_W_pdg = -24
            expected_b_pdg = -5

        else:
            truth_fail["particle_in_top_loop_is_not_top"] += 1
            truth_event_valid = False
            break

        top_decay_products = get_decay_products(
            current_top_idx,
            gen_mothers,
            gen_pdg_ids
        )

        b_candidates = [
            idx for idx in top_decay_products
            if gen_pdg_ids[idx] == expected_b_pdg
        ]

        W_candidates = [
            idx for idx in top_decay_products
            if gen_pdg_ids[idx] == expected_W_pdg
        ]

        # Require exactly the expected b and W.
        if len(b_candidates) != 1:
            truth_fail["top_does_not_have_exact_expected_b"] += 1
            truth_event_valid = False

            if event < DEBUG_GEN_EVENTS:
                print(
                    "BAD TOP DECAY: expected b PDG",
                    expected_b_pdg,
                    "from top index",
                    current_top_idx,
                    "top PDG",
                    current_top_pdg,
                    "products:",
                    [
                        (idx, gen_pdg_ids[idx])
                        for idx in top_decay_products
                    ]
                )

            break

        if len(W_candidates) != 1:
            truth_fail["top_does_not_have_exact_expected_W"] += 1
            truth_event_valid = False

            if event < DEBUG_GEN_EVENTS:
                print(
                    "BAD TOP DECAY: expected W PDG",
                    expected_W_pdg,
                    "from top index",
                    current_top_idx,
                    "top PDG",
                    current_top_pdg,
                    "products:",
                    [
                        (idx, gen_pdg_ids[idx])
                        for idx in top_decay_products
                    ]
                )

            break

        b_idx = get_last_copy(
            b_candidates[0],
            gen_mothers,
            gen_pdg_ids
        )

        W_idx = get_last_copy(
            W_candidates[0],
            gen_mothers,
            gen_pdg_ids
        )

        # Check again after following the particle copies.
        if gen_pdg_ids[b_idx] != expected_b_pdg:
            truth_fail["final_b_copy_has_wrong_pdg"] += 1
            truth_event_valid = False
            break

        if gen_pdg_ids[W_idx] != expected_W_pdg:
            truth_fail["final_W_copy_has_wrong_pdg"] += 1
            truth_event_valid = False
            break

        W_decay_type, W_decay_indices = classify_w_decay(
            W_idx,
            gen_mothers,
            gen_pdg_ids
        )

        if W_decay_type is None:
            truth_fail["W_decay_failed_pdg_checks"] += 1
            truth_event_valid = False

            if event < DEBUG_GEN_EVENTS:
                W_products = get_decay_products(
                    W_idx,
                    gen_mothers,
                    gen_pdg_ids
                )

                print(
                    "BAD W DECAY:",
                    "W index =", W_idx,
                    "W PDG =", gen_pdg_ids[W_idx],
                    "products =",
                    [
                        (idx, gen_pdg_ids[idx])
                        for idx in W_products
                    ]
                )

            break

        if event < DEBUG_GEN_EVENTS:
            print(
                "\nAccepted top decay:",
                f"top index={current_top_idx}",
                f"top PDG={current_top_pdg}",
                f"b index={b_idx}",
                f"b PDG={gen_pdg_ids[b_idx]}",
                f"W index={W_idx}",
                f"W PDG={gen_pdg_ids[W_idx]}",
                f"W decay={W_decay_type}",
                "W products=",
                [
                    (idx, gen_pdg_ids[idx])
                    for idx in W_decay_indices
                ]
            )

        if W_decay_type == "leptonic":

            if gen_b_lep_idx is not None:
                truth_fail["two_leptonic_top_decays"] += 1
                truth_event_valid = False
                break

            gen_b_lep_idx = b_idx

        elif W_decay_type == "hadronic":

            if gen_b_had_idx is not None:
                truth_fail["two_hadronic_top_decays"] += 1
                truth_event_valid = False
                break

            if len(W_decay_indices) != 2:
                truth_fail["hadronic_W_does_not_have_two_quarks"] += 1
                truth_event_valid = False
                break

            gen_b_had_idx = b_idx
            gen_w_quark_idxs = W_decay_indices

    if not truth_event_valid:
        continue

    # Require exactly one leptonic and one hadronic top decay.
    if gen_b_lep_idx is None:
        truth_fail["missing_leptonic_b"] += 1
        continue

    if gen_b_had_idx is None:
        truth_fail["missing_hadronic_b"] += 1
        continue

    if len(gen_w_quark_idxs) != 2:
        truth_fail["missing_two_hadronic_W_quarks"] += 1
        continue

    # Final explicit PDG checks.
    if abs(gen_pdg_ids[gen_b_lep_idx]) != 5:
        truth_fail["b_lep_is_not_b_quark"] += 1
        continue

    if abs(gen_pdg_ids[gen_b_had_idx]) != 5:
        truth_fail["b_had_is_not_b_quark"] += 1
        continue

    if not all(
        1 <= abs(gen_pdg_ids[idx]) <= 5
        for idx in gen_w_quark_idxs
    ):
        truth_fail["W_products_are_not_quarks"] += 1
        continue

    gen_b_lep = make_gen_vector(gen_b_lep_idx)
    gen_b_had = make_gen_vector(gen_b_had_idx)

    gen_w_quarks = [
        make_gen_vector(idx)
        for idx in gen_w_quark_idxs
    ]

    if event < DEBUG_GEN_EVENTS:
        print(
            "\nFINAL TRUTH ASSIGNMENT:",
            f"b_lep index={gen_b_lep_idx}",
            f"PDG={gen_pdg_ids[gen_b_lep_idx]}",
            f"b_had index={gen_b_had_idx}",
            f"PDG={gen_pdg_ids[gen_b_had_idx]}",
            "W quarks=",
            [
                (idx, gen_pdg_ids[idx])
                for idx in gen_w_quark_idxs
            ]
        )

    # MET filters
    if not all([
        tree.Flag_goodVertices,
        tree.Flag_globalSuperTightHalo2016Filter,
        tree.Flag_HBHENoiseFilter,
        tree.Flag_HBHENoiseIsoFilter,
        tree.Flag_EcalDeadCellTriggerPrimitiveFilter,
        tree.Flag_BadPFMuonFilter,
        tree.Flag_BadPFMuonDzFilter,
        tree.Flag_eeBadScFilter,
        tree.Flag_ecalBadCalibFilter
    ]):
        continue


    # trigger cuts
    passes_mu_trigger = any(
        getattr(tree, trig, False) for trig in cuts["Trigger"]["muon"]
        )

    passes_ele_trigger = any(
        getattr(tree, trig, False) for trig in cuts["Trigger"]["electron"]
        )   

    if passes_mu_trigger:
        cutflow["pass_mu_trigger"] += 1

    if passes_ele_trigger:
        cutflow["pass_ele_trigger"] += 1

    # muons

    muons = []
    for mu_idx in range(tree.nMuon):
        mu = MyMuon(
            tree.Muon_pt[mu_idx],
            tree.Muon_eta[mu_idx],
            tree.Muon_phi[mu_idx],
            tree.Muon_mass[mu_idx],   
            tree.Muon_miniPFRelIso_all[mu_idx],
            tree.Muon_charge[mu_idx] #unsure
            )
        muons.append(mu)

    #iso_muons = [m for m in muons if m.IsIsolated(MuonRelIsoCut)]

    iso_muons = [
    m for m in muons
    if m.Pt() > cuts["Muon"]["pt_min"]
    and abs(m.Eta()) < cuts["Muon"]["eta_max"]
    and m.isolation < cuts["Muon"]["iso_max"]
    ]



    iso_muons = sorted(iso_muons, key=lambda m: m.Pt(), reverse=True)

    #if len(iso_muons) >= 2 and iso_muons[0].Pt() > MuonPtCut:
        #dimu = iso_muons[0] + iso_muons[1]
        #h_Mmumu.Fill(dimu.M(), weight)


    # electrons
    electrons = []
    for ele_idx in range(tree.nElectron):
        ele = MyElectron(
            tree.Electron_pt[ele_idx],
            tree.Electron_eta[ele_idx],
            tree.Electron_phi[ele_idx],
            tree.Electron_mass[ele_idx],   
            tree.Electron_miniPFRelIso_all[ele_idx],  
            tree.Electron_charge[ele_idx],
            tree.Electron_cutBased[ele_idx]
            )
        electrons.append(ele)

    
    iso_electrons = [
        e for e in electrons
        if e.Pt() > cuts["Electron"]["pt_min"]
        and abs(e.Eta()) < cuts["Electron"]["eta_max"]
        and e.cutBased >= cuts["Electron"]["cutBased"]
        and e.isolation < cuts["Electron"]["iso_max"] 
        ]

    #iso_electrons = [e for e in electrons if e.IsIsolated(ElectronRelIsoCut)]
    iso_electrons = sorted(iso_electrons, key=lambda e: e.Pt(), reverse=True)

    #if len(iso_electrons) >= 2 and iso_electrons[0].Pt() > ElectronPtCut:
    #   diele = iso_electrons[0] + iso_electrons[1]
    #  h_Mee.Fill(diele.M(), weight)


    # MET from tree
    MET  = tree.MET_pt
    phi  = tree.MET_phi


    METx = MET * r.TMath.Cos(phi)
    METy = MET * r.TMath.Sin(phi)

    n_iso_mu  = len(iso_muons)
    n_iso_ele = len(iso_electrons)

    if n_iso_mu == 1 and n_iso_ele == 0:
        if not passes_mu_trigger:
            continue
        selected_lepton = iso_muons[0]

    elif n_iso_ele == 1 and n_iso_mu == 0:
        if not passes_ele_trigger:
            continue
        selected_lepton = iso_electrons[0]

    else:
        continue
    cutflow["exactly_1_lepton"] += 1
    passes_MET = MET > cuts["MET"]["pt_min"]

    if not passes_MET:
        continue
    cutflow["pass_MET"] += 1

    
    # jets

    jets = []
    for jet_idx in range(tree.nJet):
        jet = MyJet(
            tree.Jet_pt[jet_idx],
            tree.Jet_eta[jet_idx],
            tree.Jet_phi[jet_idx],
            tree.Jet_mass[jet_idx],    
            tree.Jet_btagDeepFlavB[jet_idx],    
            tree.Jet_jetId[jet_idx] 
            )
        jets.append(jet)

    good_jets = [
    j for j in jets
    if j.Pt() > cuts["Jets"]["pt_min"]
    and abs(j.Eta()) < cuts["Jets"]["eta_max"]
    and j.HasJetID()
    and j.DeltaR(selected_lepton) > 0.4
    ]

    #good_jets = [j for j in jets if j.HasJetID() and j.Pt() > JetPtCut]
    good_jets = sorted(good_jets, key=lambda j: j.Pt(), reverse=True)
    
    

    # flagging b-tagged jets
    for j in good_jets:
        j.is_btagged = j.IsBTagged(cuts["Jets"]["btag"])

    bjets = [j for j in good_jets if j.is_btagged]
    bjets = sorted(bjets, key=lambda j: j.Pt(), reverse=True)

    n_jets = len(good_jets)
    n_bjets = len(bjets)

    sigma2 = np.array([
        [100, 0],
        [0, 100]
    ])
    
    
    
    #4-6 jets
    if 4 <= n_jets <= 6:
        cutflow["4plus_jets"] += 1

        if n_bjets >= 2:
            cutflow["4pj_2b"] += 1

            b1, b2 = bjets[0], bjets[1]
            light_jets = [j for j in good_jets if not j.is_btagged]

            if len(light_jets) < 2:
                continue

            best_pair = None

            for j1_tmp, j2_tmp in combinations(light_jets, 2):

                matched = (
                    (j1_tmp.DeltaR(gen_w_quarks[0]) < 0.4 and
                    j2_tmp.DeltaR(gen_w_quarks[1]) < 0.4)
                    or
                    (j1_tmp.DeltaR(gen_w_quarks[1]) < 0.4 and
                    j2_tmp.DeltaR(gen_w_quarks[0]) < 0.4)
                )

                if matched:
                    best_pair = (j1_tmp, j2_tmp)
                    break

            if best_pair is None:
                continue

            j1, j2 = best_pair
            W_had = j1 + j2


            for b_had in [b1, b2]:

                # Fill only the correctly matched hadronic b
                if b_had.DeltaR(gen_b_had) >= 0.4:
                    continue

                t_had = W_had + b_had

                h_Mwh_vs_Mth.Fill(
                    t_had.M(),
                    W_had.M(),
                    weight
                )

    # 3-jet reconstruction
    if n_jets == 3:
        cutflow["3jets"] += 1

        # exactly two b-tagged jets and one light jet
        if n_bjets != 2:
            continue

        cutflow["3j_2b"] += 1

        b1, b2 = bjets[0], bjets[1]
        light_jets = [j for j in good_jets if not j.is_btagged]

        if len(light_jets) != 1:
            continue

        n_3jet_before_solver += 1

        light_jet = light_jets[0]

        light_is_correct = (
            light_jet.DeltaR(gen_w_quarks[0]) < 0.4
            or light_jet.DeltaR(gen_w_quarks[1]) < 0.4
        )

        assignments = []

        for b_lep, b_had in [(b1, b2), (b2, b1)]:

            try:
                nusol = singleNeutrinoSolution(
                    b_lep,
                    selected_lepton,
                    METx,
                    METy,
                    sigma2
                )
            except Exception as error:
                n_3jet_solver_fail += 1
                continue

            n_3jet_solver_success += 1

            nu = make_neutrino(nusol)

            Dn = nusol.chi2
            Mbhj = (b_had + light_jet).M()
            if not np.isfinite(Dn):
                continue

            if not np.isfinite(Mbhj):
                continue

            b_lep_correct = b_lep.DeltaR(gen_b_lep) < 0.4
            b_had_correct = b_had.DeltaR(gen_b_had) < 0.4

            # Plot 1: Dn for correct/wrong leptonic b
            if b_lep_correct:
                h_Dn_correct.Fill(Dn)
            else:
                h_Dn_wrong.Fill(Dn)

            # Plot 2: Dn for correct/wrong hadronic b candidate
            if b_had_correct:
                h_Dn_bh_correct.Fill(Dn)
            else:
                h_Dn_bh_wrong.Fill(Dn)

            # Plot 3: mass of bh + light jet
            if b_had_correct and light_is_correct:
                h_Mbhj_correct.Fill(Mbhj)
            else:
                h_Mbhj_wrong.Fill(Mbhj)

            # Cuts used only for accepted reconstruction assignments
            if Dn > 150 or Mbhj > 500:
                continue

            assignments.append({
                "b_lep": b_lep,
                "b_had": b_had,
                "nu": nu,
                "Dn": Dn,
                "Mbhj": Mbhj
            })

        # No assignment produced a valid neutrino solution
        if len(assignments) == 0:
            continue

        # Only one b candidate produced a valid solution:
        # that candidate is the leptonic b.
        if len(assignments) == 1:
            best_assignment = assignments[0]

        # Both candidates produced solutions.
        # The likelihood selection must be done later using
        # probability templates from a separate first pass.
        else:
            best_assignment = None


def normalize_hist(hist):
    integral = hist.Integral()

    if integral > 0:
        hist.Scale(1.0 / integral)

print("Dn correct:", h_Dn_correct.GetEntries())
print("Dn wrong:", h_Dn_wrong.GetEntries())
print("Dn bh correct:", h_Dn_bh_correct.GetEntries())
print("Dn bh wrong:", h_Dn_bh_wrong.GetEntries())
print("Mass correct:", h_Mbhj_correct.GetEntries())
print("Mass wrong:", h_Mbhj_wrong.GetEntries())
print("3-jet events before solver:", n_3jet_before_solver)
print("3-jet solver successes:", n_3jet_solver_success)
print("3-jet solver failures:", n_3jet_solver_fail)

print("\n=== GENERATOR TRUTH FAILURES ===")

for failure_name, failure_count in truth_fail.items():
    print(f"{failure_name:40s}: {failure_count}")

for hist in [
    h_Dn_correct,
    h_Dn_wrong,
    h_Dn_bh_correct,
    h_Dn_bh_wrong,
    h_Mbhj_correct,
    h_Mbhj_wrong
]:
    normalize_hist(hist)

# histograms

print("\n=== CUTFLOW ===")
for key, val in cutflow.items():
    print(f"{key:15s}: {val}")



#probability 2d hist

c_Mwh_vs_Mth = r.TCanvas("c_Mwh_vs_Mth", "M(W_h) vs M(t_h)", 800, 600)

total = h_Mwh_vs_Mth.Integral()

if total > 0:
    h_Mwh_vs_Mth.Scale(1.0 / total)

print("Probability sum:", h_Mwh_vs_Mth.Integral())

def top_probability(M_top, M_W, hist):
    return max(0.0, hist.Interpolate(M_top, M_W))


#p = top_probability(173.2, 81.1, h_Mwh_vs_Mth)
#print(p)

h_Mwh_vs_Mth.Draw("COLZ")

legend = r.TLegend(0.15, 0.80, 0.45, 0.88)
legend.SetBorderSize(0)
legend.SetFillStyle(0)
legend.AddEntry(h_Mwh_vs_Mth,
                "Color = probability",
                "f")
c_Mwh_vs_Mth.Update()


import os
os.makedirs("plots", exist_ok=True)
c_Mwh_vs_Mth.SaveAs("plots/h_Mwh_vs_Mth.png")

canvases = []


def save_comparison(
    correct_hist,
    wrong_hist,
    canvas_name,
    output_name
):
    canvas = r.TCanvas(canvas_name, canvas_name, 800, 600)
    canvases.append(canvas)

    correct_hist.SetLineColor(r.kBlue)
    wrong_hist.SetLineColor(r.kRed)

    correct_hist.SetLineWidth(2)
    wrong_hist.SetLineWidth(2)

    if correct_hist.GetMaximum() >= wrong_hist.GetMaximum():
        correct_hist.Draw("HIST")
        wrong_hist.Draw("HIST SAME")
    else:
        wrong_hist.Draw("HIST")
        correct_hist.Draw("HIST SAME")

    legend = r.TLegend(0.58, 0.68, 0.88, 0.88)
    legend.SetBorderSize(0)
    legend.SetFillStyle(0)

    legend.AddEntry(correct_hist,
                    "Blue: correct assignment",
                    "l")
    legend.AddEntry(wrong_hist,
                    "Red: wrong assignment",
                    "l")

    legend.Draw()

    canvas.Update()
    canvas.Draw()
    canvas.SaveAs(output_name)

    return canvas


c_Dn_leptonic = save_comparison(
    h_Dn_correct,
    h_Dn_wrong,
    "c_Dn_leptonic",
    "plots/Dn_leptonic_b.png"
)

c_Dn_hadronic = save_comparison(
    h_Dn_bh_correct,
    h_Dn_bh_wrong,
    "c_Dn_hadronic",
    "plots/Dn_hadronic_b.png"
)

c_Mbhj = save_comparison(
    h_Mbhj_correct,
    h_Mbhj_wrong,
    "c_Mbhj",
    "plots/Mbhj_3jet.png"
)
# Out:
# Warning in <TClass::Init>: no dictionary for class edm::Hash<1> is available
# Warning in <TClass::Init>: no dictionary for class edm::ProcessHistory is available
# Warning in <TClass::Init>: no dictionary for class edm::ProcessConfiguration is available
# Warning in <TClass::Init>: no dictionary for class edm::ParameterSetBlob is available
# Warning in <TClass::Init>: no dictionary for class pair<edm::Hash<1>,edm::ParameterSetBlob> is available
# Events in file: 197164
#
# ========== GENERATOR EVENT 0 ==========
# idx=  0  pdg=   21  mother_idx= -1  mother_pdg= None  lastCopy=False
# idx=  1  pdg=   21  mother_idx= -1  mother_pdg= None  lastCopy=False
# idx=  2  pdg=   -6  mother_idx=  0  mother_pdg=   21  lastCopy=False
# idx=  3  pdg=    6  mother_idx=  0  mother_pdg=   21  lastCopy=False
# idx=  4  pdg=   21  mother_idx=  0  mother_pdg=   21  lastCopy=False
# idx=  5  pdg=   -6  mother_idx=  2  mother_pdg=   -6  lastCopy=True
# idx=  6  pdg=    6  mother_idx=  3  mother_pdg=    6  lastCopy=True
# idx=  7  pdg=  -24  mother_idx=  5  mother_pdg=   -6  lastCopy=False
# idx=  8  pdg=   -5  mother_idx=  5  mother_pdg=   -6  lastCopy=False
# idx=  9  pdg=  -24  mother_idx=  7  mother_pdg=  -24  lastCopy=True
# idx= 10  pdg=   24  mother_idx=  6  mother_pdg=    6  lastCopy=False
# idx= 11  pdg=    5  mother_idx=  6  mother_pdg=    6  lastCopy=False
# idx= 12  pdg=   24  mother_idx= 10  mother_pdg=   24  lastCopy=True
# idx= 13  pdg=   15  mother_idx=  9  mother_pdg=  -24  lastCopy=False
# idx= 14  pdg=  -16  mother_idx=  9  mother_pdg=  -24  lastCopy=False
# idx= 15  pdg=   15  mother_idx= 13  mother_pdg=   15  lastCopy=True
# idx= 16  pdg=   22  mother_idx= 13  mother_pdg=   15  lastCopy=True
# idx= 17  pdg=  -16  mother_idx= 14  mother_pdg=  -16  lastCopy=True
# idx= 18  pdg=    2  mother_idx= 12  mother_pdg=   24  lastCopy=False
# idx= 19  pdg=   -1  mother_idx= 12  mother_pdg=   24  lastCopy=False
# idx= 20  pdg=    2  mother_idx= -1  mother_pdg= None  lastCopy=True
# idx= 21  pdg=    2  mother_idx= 18  mother_pdg=    2  lastCopy=True
# idx= 22  pdg=   -1  mother_idx= 19  mother_pdg=   -1  lastCopy=True
# idx= 23  pdg=    3  mother_idx= -1  mother_pdg= None  lastCopy=True
# idx= 24  pdg=   21  mother_idx= -1  mother_pdg= None  lastCopy=True
# idx= 25  pdg=   -2  mother_idx= -1  mother_pdg= None  lastCopy=True
# idx= 26  pdg=    3  mother_idx= -1  mother_pdg= None  lastCopy=True
# idx= 27  pdg=   21  mother_idx=  8  mother_pdg=   -5  lastCopy=True
# idx= 28  pdg=   21  mother_idx=  8  mother_pdg=   -5  lastCopy=True
# idx= 29  pdg=   21  mother_idx=  8  mother_pdg=   -5  lastCopy=True
# idx= 30  pdg=   21  mother_idx=  8  mother_pdg=   -5  lastCopy=True
# idx= 31  pdg=   -5  mother_idx=  8  mother_pdg=   -5  lastCopy=True
# idx= 32  pdg=  511  mother_idx=  8  mother_pdg=   -5  lastCopy=True
# idx= 33  pdg=    5  mother_idx= 11  mother_pdg=    5  lastCopy=True
# idx= 34  pdg=   21  mother_idx= 11  mother_pdg=    5  lastCopy=True
# idx= 35  pdg=   -2  mother_idx= -1  mother_pdg= None  lastCopy=True
# idx= 36  pdg= -513  mother_idx= 11  mother_pdg=    5  lastCopy=True
# idx= 37  pdg=   21  mother_idx=  4  mother_pdg=   21  lastCopy=True
# idx= 38  pdg=   21  mother_idx=  4  mother_pdg=   21  lastCopy=True
# idx= 39  pdg=   21  mother_idx=  4  mother_pdg=   21  lastCopy=True
# idx= 40  pdg=   21  mother_idx=  4  mother_pdg=   21  lastCopy=True
# idx= 41  pdg=   21  mother_idx=  4  mother_pdg=   21  lastCopy=True
# idx= 42  pdg=   21  mother_idx=  4  mother_pdg=   21  lastCopy=True
# idx= 43  pdg=   21  mother_idx=  4  mother_pdg=   21  lastCopy=True
# idx= 44  pdg=   21  mother_idx=  4  mother_pdg=   21  lastCopy=True
# idx= 45  pdg=   21  mother_idx=  4  mother_pdg=   21  lastCopy=True
# idx= 46  pdg=  111  mother_idx= 37  mother_pdg=   21  lastCopy=True
# idx= 47  pdg=   16  mother_idx= 15  mother_pdg=   15  lastCopy=True
# idx= 48  pdg=  111  mother_idx= 15  mother_pdg=   15  lastCopy=True
# idx= 49  pdg= -211  mother_idx= 15  mother_pdg=   15  lastCopy=True
# idx= 50  pdg= -413  mother_idx= 32  mother_pdg=  511  lastCopy=True
# idx= 51  pdg=  411  mother_idx= 32  mother_pdg=  511  lastCopy=True
# idx= 52  pdg= -511  mother_idx= 36  mother_pdg= -513  lastCopy=True
# idx= 53  pdg=   22  mother_idx= 46  mother_pdg=  111  lastCopy=True
# idx= 54  pdg=   11  mother_idx=  8  mother_pdg=   -5  lastCopy=True
# idx= 55  pdg=  -11  mother_idx=  8  mother_pdg=   -5  lastCopy=True
# idx= 56  pdg=   22  mother_idx= 48  mother_pdg=  111  lastCopy=True
# idx= 57  pdg=   22  mother_idx= 48  mother_pdg=  111  lastCopy=True
# idx= 58  pdg=   11  mother_idx= 23  mother_pdg=    3  lastCopy=True
# idx= 59  pdg=  -11  mother_idx= 23  mother_pdg=    3  lastCopy=True
# idx= 60  pdg= -411  mother_idx= 50  mother_pdg= -413  lastCopy=True
# idx= 61  pdg=-4232  mother_idx= 52  mother_pdg= -511  lastCopy=True
# idx= 62  pdg=   11  mother_idx= 60  mother_pdg= -411  lastCopy=True
# idx= 63  pdg=  -12  mother_idx= 60  mother_pdg= -411  lastCopy=True
#
# Accepted top decay: top index=6 top PDG=6 b index=33 b PDG=5 W index=12 W PDG=24 W decay=hadronic W products= [(21, 2), (22, -1)]
#
# Accepted top decay: top index=5 top PDG=-6 b index=31 b PDG=-5 W index=9 W PDG=-24 W decay=leptonic W products= [(13, 15), (14, -16)]
#
# FINAL TRUTH ASSIGNMENT: b_lep index=31 PDG=-5 b_had index=33 PDG=5 W quarks= [(21, 2), (22, -1)]
#
# ========== GENERATOR EVENT 1 ==========
# idx=  0  pdg=    2  mother_idx= -1  mother_pdg= None  lastCopy=False
# idx=  1  pdg=   21  mother_idx= -1  mother_pdg= None  lastCopy=True
# idx=  2  pdg=   -6  mother_idx=  0  mother_pdg=    2  lastCopy=False
# idx=  3  pdg=    6  mother_idx=  0  mother_pdg=    2  lastCopy=False
# idx=  4  pdg=    2  mother_idx=  0  mother_pdg=    2  lastCopy=False
# idx=  5  pdg=   -6  mother_idx=  2  mother_pdg=   -6  lastCopy=True
# idx=  6  pdg=    6  mother_idx=  3  mother_pdg=    6  lastCopy=True
# idx=  7  pdg=  -24  mother_idx=  5  mother_pdg=   -6  lastCopy=False
# idx=  8  pdg=   -5  mother_idx=  5  mother_pdg=   -6  lastCopy=False
# idx=  9  pdg=  -24  mother_idx=  7  mother_pdg=  -24  lastCopy=True
# idx= 10  pdg=   24  mother_idx=  6  mother_pdg=    6  lastCopy=False
# idx= 11  pdg=    5  mother_idx=  6  mother_pdg=    6  lastCopy=False
# idx= 12  pdg=   24  mother_idx= 10  mother_pdg=   24  lastCopy=True
# idx= 13  pdg=    3  mother_idx=  9  mother_pdg=  -24  lastCopy=False
# idx= 14  pdg=   -4  mother_idx=  9  mother_pdg=  -24  lastCopy=False
# idx= 15  pdg=    3  mother_idx= 13  mother_pdg=    3  lastCopy=True
# idx= 16  pdg=   -4  mother_idx= 14  mother_pdg=   -4  lastCopy=True
# idx= 17  pdg=  -11  mother_idx= 12  mother_pdg=   24  lastCopy=False
# idx= 18  pdg=   12  mother_idx= 12  mother_pdg=   24  lastCopy=False
# idx= 19  pdg=  -11  mother_idx= 17  mother_pdg=  -11  lastCopy=True
# idx= 20  pdg=   22  mother_idx= 17  mother_pdg=  -11  lastCopy=True
# idx= 21  pdg=   12  mother_idx= 18  mother_pdg=   12  lastCopy=True
# idx= 22  pdg= -421  mother_idx= 13  mother_pdg=    3  lastCopy=True
# idx= 23  pdg=    1  mother_idx=  2  mother_pdg=   -6  lastCopy=True
# idx= 24  pdg=   21  mother_idx=  8  mother_pdg=   -5  lastCopy=True
# idx= 25  pdg=   21  mother_idx=  8  mother_pdg=   -5  lastCopy=True
# idx= 26  pdg=   -5  mother_idx=  8  mother_pdg=   -5  lastCopy=True
# idx= 27  pdg=  513  mother_idx=  2  mother_pdg=   -6  lastCopy=True
# idx= 28  pdg=    2  mother_idx=  4  mother_pdg=    2  lastCopy=True
# idx= 29  pdg=   21  mother_idx=  4  mother_pdg=    2  lastCopy=True
# idx= 30  pdg=    5  mother_idx= 11  mother_pdg=    5  lastCopy=True
# idx= 31  pdg=   21  mother_idx= 11  mother_pdg=    5  lastCopy=True
# idx= 32  pdg= -533  mother_idx= 11  mother_pdg=    5  lastCopy=True
# idx= 33  pdg=   11  mother_idx=  2  mother_pdg=   -6  lastCopy=True
# idx= 34  pdg=  -11  mother_idx=  2  mother_pdg=   -6  lastCopy=True
# idx= 35  pdg=  511  mother_idx= 27  mother_pdg=  513  lastCopy=True
# idx= 36  pdg= -531  mother_idx= 32  mother_pdg= -533  lastCopy=True
# idx= 37  pdg=   11  mother_idx= 13  mother_pdg=    3  lastCopy=True
# idx= 38  pdg=  -11  mother_idx= 13  mother_pdg=    3  lastCopy=True
# idx= 39  pdg=  413  mother_idx= 35  mother_pdg=  511  lastCopy=True
# idx= 40  pdg= -411  mother_idx= 35  mother_pdg=  511  lastCopy=True
# idx= 41  pdg=  433  mother_idx= 36  mother_pdg= -531  lastCopy=True
# idx= 42  pdg= -413  mother_idx= 36  mother_pdg= -531  lastCopy=True
# idx= 43  pdg=  421  mother_idx= 39  mother_pdg=  413  lastCopy=True
# idx= 44  pdg=   11  mother_idx= 40  mother_pdg= -411  lastCopy=True
# idx= 45  pdg=  -12  mother_idx= 40  mother_pdg= -411  lastCopy=True
# idx= 46  pdg=  431  mother_idx= 41  mother_pdg=  433  lastCopy=True
# idx= 47  pdg= -421  mother_idx= 42  mother_pdg= -413  lastCopy=True
# idx= 48  pdg=  221  mother_idx= 46  mother_pdg=  431  lastCopy=True
# idx= 49  pdg=   13  mother_idx= 47  mother_pdg= -421  lastCopy=True
# idx= 50  pdg=  -14  mother_idx= 47  mother_pdg= -421  lastCopy=True
# idx= 51  pdg=   22  mother_idx= 48  mother_pdg=  221  lastCopy=True
#
# Accepted top decay: top index=6 top PDG=6 b index=30 b PDG=5 W index=12 W PDG=24 W decay=leptonic W products= [(17, -11), (18, 12)]
#
# Accepted top decay: top index=5 top PDG=-6 b index=26 b PDG=-5 W index=9 W PDG=-24 W decay=hadronic W products= [(15, 3), (16, -4)]
#
# FINAL TRUTH ASSIGNMENT: b_lep index=30 PDG=5 b_had index=26 PDG=-5 W quarks= [(15, 3), (16, -4)]
# WARNING: multiple same-PDG children: parent = 14 pdg = -1 children = [23, 28]
# WARNING: multiple same-PDG children: parent = 17 pdg = -3 children = [27, 30]
# WARNING: multiple same-PDG children: parent = 19 pdg = -1 children = [23, 30]
# WARNING: multiple same-PDG children: parent = 13 pdg = -2 children = [18, 24]
# WARNING: multiple same-PDG children: parent = 8 pdg = 5 children = [24, 30]
# WARNING: multiple same-PDG children: parent = 11 pdg = -5 children = [21, 22]
# WARNING: multiple same-PDG children: parent = 16 pdg = 2 children = [20, 23]
# WARNING: multiple same-PDG children: parent = 13 pdg = 4 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 11 pdg = 5 children = [20, 21]
# WARNING: multiple same-PDG children: parent = 8 pdg = 5 children = [17, 23]
# WARNING: multiple same-PDG children: parent = 19 pdg = -4 children = [20, 23]
# WARNING: multiple same-PDG children: parent = 15 pdg = -3 children = [18, 19]
# WARNING: multiple same-PDG children: parent = 14 pdg = 2 children = [18, 20]
# WARNING: multiple same-PDG children: parent = 22 pdg = -2 children = [24, 32]
# WARNING: multiple same-PDG children: parent = 11 pdg = 5 children = [25, 28]
# WARNING: multiple same-PDG children: parent = 11 pdg = -5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [16, 17, 18]
# WARNING: multiple same-PDG children: parent = 13 pdg = 5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 7 pdg = 5 children = [8, 20]
# WARNING: multiple same-PDG children: parent = 13 pdg = -4 children = [19, 25]
# WARNING: multiple same-PDG children: parent = 11 pdg = -5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 11 pdg = -5 children = [18, 19]
# WARNING: multiple same-PDG children: parent = 11 pdg = 5 children = [21, 22]
# WARNING: multiple same-PDG children: parent = 11 pdg = -5 children = [12, 20]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 17 pdg = -1 children = [19, 27]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 16 pdg = -2 children = [17, 25]
# WARNING: multiple same-PDG children: parent = 14 pdg = 3 children = [21, 25]
# WARNING: multiple same-PDG children: parent = 13 pdg = 4 children = [20, 32]
# WARNING: multiple same-PDG children: parent = 14 pdg = 5 children = [20, 21]
# WARNING: multiple same-PDG children: parent = 8 pdg = 5 children = [20, 26]
# WARNING: multiple same-PDG children: parent = 14 pdg = -3 children = [21, 28]
# WARNING: multiple same-PDG children: parent = 12 pdg = 4 children = [16, 22]
# WARNING: multiple same-PDG children: parent = 13 pdg = 2 children = [16, 20]
# WARNING: multiple same-PDG children: parent = 13 pdg = -2 children = [14, 20]
# WARNING: multiple same-PDG children: parent = 15 pdg = -3 children = [21, 27]
# WARNING: multiple same-PDG children: parent = 11 pdg = -5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 16 pdg = -2 children = [17, 20]
# WARNING: multiple same-PDG children: parent = 13 pdg = -3 children = [18, 22]
# WARNING: multiple same-PDG children: parent = 13 pdg = 1 children = [21, 28]
# WARNING: multiple same-PDG children: parent = 9 pdg = -5 children = [20, 32]
# WARNING: multiple same-PDG children: parent = 9 pdg = -5 children = [15, 16]
# WARNING: multiple same-PDG children: parent = 7 pdg = -5 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 14 pdg = 2 children = [16, 21]
# WARNING: multiple same-PDG children: parent = 7 pdg = 5 children = [23, 26]
# WARNING: multiple same-PDG children: parent = 8 pdg = 5 children = [9, 23]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [21, 22]
# WARNING: multiple same-PDG children: parent = 13 pdg = 5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 23 pdg = -3 children = [24, 46]
# WARNING: multiple same-PDG children: parent = 10 pdg = 5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 18 pdg = 3 children = [22, 27]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [12, 24]
# WARNING: multiple same-PDG children: parent = 13 pdg = 1 children = [20, 21]
# WARNING: multiple same-PDG children: parent = 12 pdg = 2 children = [14, 19]
# WARNING: multiple same-PDG children: parent = 22 pdg = -3 children = [23, 25]
# WARNING: multiple same-PDG children: parent = 20 pdg = -3 children = [26, 29]
# WARNING: multiple same-PDG children: parent = 9 pdg = 5 children = [18, 19]
# WARNING: multiple same-PDG children: parent = 14 pdg = 1 children = [16, 23]
# WARNING: multiple same-PDG children: parent = 15 pdg = -1 children = [23, 25]
# WARNING: multiple same-PDG children: parent = 12 pdg = -3 children = [19, 21]
# WARNING: multiple same-PDG children: parent = 13 pdg = 2 children = [22, 25]
# WARNING: multiple same-PDG children: parent = 14 pdg = -1 children = [15, 18]
# WARNING: multiple same-PDG children: parent = 11 pdg = 1 children = [18, 19]
# WARNING: multiple same-PDG children: parent = 16 pdg = -4 children = [18, 32]
# WARNING: multiple same-PDG children: parent = 13 pdg = -5 children = [22, 23]
# WARNING: multiple same-PDG children: parent = 11 pdg = 3 children = [15, 20]
# WARNING: multiple same-PDG children: parent = 20 pdg = 2 children = [23, 28]
# WARNING: multiple same-PDG children: parent = 12 pdg = -5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 22 pdg = -1 children = [24, 31]
# WARNING: multiple same-PDG children: parent = 14 pdg = -3 children = [19, 28]
# WARNING: multiple same-PDG children: parent = 11 pdg = 5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 14 pdg = -4 children = [15, 22]
# WARNING: multiple same-PDG children: parent = 13 pdg = -3 children = [14, 20]
# WARNING: multiple same-PDG children: parent = 11 pdg = 5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 10 pdg = 5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 15 pdg = -2 children = [27, 31]
# WARNING: multiple same-PDG children: parent = 7 pdg = -5 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 13 pdg = -4 children = [14, 30]
# WARNING: multiple same-PDG children: parent = 13 pdg = 5 children = [22, 23]
# WARNING: multiple same-PDG children: parent = 17 pdg = 3 children = [19, 22]
# WARNING: multiple same-PDG children: parent = 13 pdg = 1 children = [18, 25]
# WARNING: multiple same-PDG children: parent = 10 pdg = 5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 14 pdg = -2 children = [17, 19]
# WARNING: multiple same-PDG children: parent = 14 pdg = -2 children = [27, 32]
# WARNING: multiple same-PDG children: parent = 17 pdg = -2 children = [18, 29]
# WARNING: multiple same-PDG children: parent = 18 pdg = -2 children = [24, 46]
# WARNING: multiple same-PDG children: parent = 18 pdg = -3 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 8 pdg = 5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 12 pdg = -3 children = [19, 25]
# WARNING: multiple same-PDG children: parent = 13 pdg = -2 children = [14, 27]
# WARNING: multiple same-PDG children: parent = 13 pdg = 2 children = [20, 24]
# WARNING: multiple same-PDG children: parent = 11 pdg = -5 children = [18, 19]
# WARNING: multiple same-PDG children: parent = 8 pdg = -5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 7 pdg = 5 children = [18, 19]
# WARNING: multiple same-PDG children: parent = 13 pdg = 1 children = [15, 19]
# WARNING: multiple same-PDG children: parent = 11 pdg = 5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 12 pdg = 2 children = [20, 28]
# WARNING: multiple same-PDG children: parent = 15 pdg = -3 children = [22, 25]
# WARNING: multiple same-PDG children: parent = 14 pdg = 1 children = [21, 26]
# WARNING: multiple same-PDG children: parent = 13 pdg = -2 children = [15, 28]
# WARNING: multiple same-PDG children: parent = 12 pdg = -3 children = [18, 20]
# WARNING: multiple same-PDG children: parent = 7 pdg = -5 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 16 pdg = -1 children = [18, 19]
# WARNING: multiple same-PDG children: parent = 13 pdg = 2 children = [24, 28]
# WARNING: multiple same-PDG children: parent = 16 pdg = -2 children = [20, 25]
# WARNING: multiple same-PDG children: parent = 10 pdg = 5 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 12 pdg = 2 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [18, 19, 20]
# WARNING: multiple same-PDG children: parent = 15 pdg = -3 children = [28, 31]
# WARNING: multiple same-PDG children: parent = 15 pdg = -1 children = [16, 24]
# WARNING: multiple same-PDG children: parent = 16 pdg = -3 children = [17, 23]
# WARNING: multiple same-PDG children: parent = 18 pdg = 2 children = [20, 29]
# WARNING: multiple same-PDG children: parent = 16 pdg = -2 children = [19, 27]
# WARNING: multiple same-PDG children: parent = 11 pdg = 2 children = [21, 24]
# WARNING: multiple same-PDG children: parent = 12 pdg = -1 children = [18, 22]
# WARNING: multiple same-PDG children: parent = 8 pdg = 5 children = [23, 24]
# WARNING: multiple same-PDG children: parent = 13 pdg = 4 children = [15, 16]
# WARNING: multiple same-PDG children: parent = 17 pdg = 1 children = [21, 31]
# WARNING: multiple same-PDG children: parent = 13 pdg = 4 children = [17, 28]
# WARNING: multiple same-PDG children: parent = 8 pdg = -5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 14 pdg = 1 children = [16, 18]
# WARNING: multiple same-PDG children: parent = 7 pdg = 5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 12 pdg = -3 children = [13, 18]
# WARNING: multiple same-PDG children: parent = 13 pdg = 1 children = [17, 25]
# WARNING: multiple same-PDG children: parent = 11 pdg = 5 children = [23, 24]
# WARNING: multiple same-PDG children: parent = 11 pdg = -5 children = [18, 19]
# WARNING: multiple same-PDG children: parent = 17 pdg = 1 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 14 pdg = -1 children = [15, 22]
# WARNING: multiple same-PDG children: parent = 15 pdg = -2 children = [20, 31]
# WARNING: multiple same-PDG children: parent = 11 pdg = 2 children = [17, 19]
# WARNING: multiple same-PDG children: parent = 10 pdg = 5 children = [22, 23]
# WARNING: multiple same-PDG children: parent = 17 pdg = -3 children = [24, 32]
# WARNING: multiple same-PDG children: parent = 18 pdg = -1 children = [20, 22]
# WARNING: multiple same-PDG children: parent = 13 pdg = -5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 7 pdg = -5 children = [24, 27]
# WARNING: multiple same-PDG children: parent = 15 pdg = 1 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 8 pdg = 5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 14 pdg = -5 children = [23, 24]
# WARNING: multiple same-PDG children: parent = 14 pdg = -1 children = [23, 27]
# WARNING: multiple same-PDG children: parent = 14 pdg = 2 children = [21, 32]
# WARNING: multiple same-PDG children: parent = 16 pdg = 2 children = [24, 26]
# WARNING: multiple same-PDG children: parent = 14 pdg = -1 children = [18, 22]
# WARNING: multiple same-PDG children: parent = 19 pdg = 1 children = [21, 29]
# WARNING: multiple same-PDG children: parent = 15 pdg = -3 children = [22, 27]
# WARNING: multiple same-PDG children: parent = 18 pdg = -2 children = [19, 23]
# WARNING: multiple same-PDG children: parent = 16 pdg = -2 children = [21, 27]
# WARNING: multiple same-PDG children: parent = 13 pdg = -1 children = [16, 18]
# WARNING: multiple same-PDG children: parent = 10 pdg = 5 children = [20, 21]
# WARNING: multiple same-PDG children: parent = 16 pdg = 2 children = [18, 21]
# WARNING: multiple same-PDG children: parent = 13 pdg = -3 children = [21, 25]
# WARNING: multiple same-PDG children: parent = 13 pdg = -1 children = [26, 31]
# WARNING: multiple same-PDG children: parent = 15 pdg = -1 children = [24, 26]
# WARNING: multiple same-PDG children: parent = 11 pdg = -5 children = [20, 21]
# WARNING: multiple same-PDG children: parent = 13 pdg = 3 children = [22, 23]
# WARNING: multiple same-PDG children: parent = 11 pdg = -5 children = [20, 25]
# WARNING: multiple same-PDG children: parent = 17 pdg = 1 children = [22, 29]
# WARNING: multiple same-PDG children: parent = 11 pdg = 4 children = [15, 21]
# WARNING: multiple same-PDG children: parent = 20 pdg = -1 children = [21, 28]
# WARNING: multiple same-PDG children: parent = 18 pdg = 1 children = [21, 33]
# WARNING: multiple same-PDG children: parent = 13 pdg = -1 children = [20, 31]
# WARNING: multiple same-PDG children: parent = 13 pdg = -3 children = [16, 21]
# WARNING: multiple same-PDG children: parent = 14 pdg = -3 children = [24, 26]
# WARNING: multiple same-PDG children: parent = 15 pdg = -1 children = [16, 20]
# WARNING: multiple same-PDG children: parent = 15 pdg = -2 children = [21, 24]
# WARNING: multiple same-PDG children: parent = 11 pdg = 4 children = [20, 24]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 13 pdg = 2 children = [22, 27]
# WARNING: multiple same-PDG children: parent = 13 pdg = 2 children = [15, 33]
# WARNING: multiple same-PDG children: parent = 9 pdg = -5 children = [18, 19]
# WARNING: multiple same-PDG children: parent = 12 pdg = 2 children = [16, 22]
# WARNING: multiple same-PDG children: parent = 9 pdg = 5 children = [22, 37]
# WARNING: multiple same-PDG children: parent = 17 pdg = 3 children = [19, 22]
# WARNING: multiple same-PDG children: parent = 15 pdg = -2 children = [20, 24]
# WARNING: multiple same-PDG children: parent = 18 pdg = 3 children = [22, 24]
# WARNING: multiple same-PDG children: parent = 13 pdg = 3 children = [22, 23]
# WARNING: multiple same-PDG children: parent = 12 pdg = 2 children = [21, 24]
# WARNING: multiple same-PDG children: parent = 8 pdg = -5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 8 pdg = 5 children = [21, 23]
# WARNING: multiple same-PDG children: parent = 14 pdg = -1 children = [23, 26]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 9 pdg = -5 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 16 pdg = -4 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 7 pdg = 5 children = [18, 19]
# WARNING: multiple same-PDG children: parent = 19 pdg = -2 children = [29, 31]
# WARNING: multiple same-PDG children: parent = 8 pdg = 5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 15 pdg = 2 children = [19, 22]
# WARNING: multiple same-PDG children: parent = 7 pdg = 5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 14 pdg = -4 children = [21, 27]
# WARNING: multiple same-PDG children: parent = 12 pdg = -1 children = [20, 21]
# WARNING: multiple same-PDG children: parent = 11 pdg = -5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 14 pdg = -1 children = [21, 24]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 13 pdg = 4 children = [21, 32]
# WARNING: multiple same-PDG children: parent = 13 pdg = 1 children = [20, 24]
# WARNING: multiple same-PDG children: parent = 14 pdg = -3 children = [21, 24]
# WARNING: multiple same-PDG children: parent = 13 pdg = 4 children = [16, 22]
# WARNING: multiple same-PDG children: parent = 9 pdg = 5 children = [10, 21]
# WARNING: multiple same-PDG children: parent = 14 pdg = 3 children = [16, 26]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 19 pdg = 1 children = [26, 30]
# WARNING: multiple same-PDG children: parent = 11 pdg = -5 children = [21, 22]
# WARNING: multiple same-PDG children: parent = 15 pdg = -3 children = [18, 23]
# WARNING: multiple same-PDG children: parent = 19 pdg = -2 children = [25, 30]
# WARNING: multiple same-PDG children: parent = 16 pdg = 3 children = [19, 28]
# WARNING: multiple same-PDG children: parent = 15 pdg = -4 children = [17, 21]
# WARNING: multiple same-PDG children: parent = 15 pdg = -1 children = [22, 25]
# WARNING: multiple same-PDG children: parent = 12 pdg = -1 children = [18, 22]
# WARNING: multiple same-PDG children: parent = 8 pdg = 5 children = [18, 22]
# WARNING: multiple same-PDG children: parent = 15 pdg = 2 children = [23, 31]
# WARNING: multiple same-PDG children: parent = 12 pdg = -1 children = [13, 22]
# WARNING: multiple same-PDG children: parent = 12 pdg = -3 children = [17, 23]
# WARNING: multiple same-PDG children: parent = 10 pdg = 5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 15 pdg = -4 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 15 pdg = -3 children = [18, 22]
# WARNING: multiple same-PDG children: parent = 13 pdg = -5 children = [20, 21]
# WARNING: multiple same-PDG children: parent = 11 pdg = 2 children = [18, 25]
# WARNING: multiple same-PDG children: parent = 12 pdg = -3 children = [15, 18]
# WARNING: multiple same-PDG children: parent = 10 pdg = 5 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 12 pdg = 1 children = [23, 30]
# WARNING: multiple same-PDG children: parent = 11 pdg = 5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 11 pdg = -5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 14 pdg = -4 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 15 pdg = 1 children = [18, 19]
# WARNING: multiple same-PDG children: parent = 16 pdg = 1 children = [17, 26]
# WARNING: multiple same-PDG children: parent = 14 pdg = -3 children = [25, 28]
# WARNING: multiple same-PDG children: parent = 14 pdg = 5 children = [23, 24]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [12, 24]
# WARNING: multiple same-PDG children: parent = 10 pdg = 5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 10 pdg = 5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 16 pdg = -3 children = [20, 26]
# WARNING: multiple same-PDG children: parent = 11 pdg = 5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 7 pdg = 5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 7 pdg = -5 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 8 pdg = 5 children = [21, 22]
# WARNING: multiple same-PDG children: parent = 17 pdg = -3 children = [18, 29]
# WARNING: multiple same-PDG children: parent = 16 pdg = -2 children = [19, 21]
# WARNING: multiple same-PDG children: parent = 14 pdg = -4 children = [18, 22]
# WARNING: multiple same-PDG children: parent = 8 pdg = -5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 16 pdg = -3 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 11 pdg = 1 children = [17, 19]
# WARNING: multiple same-PDG children: parent = 13 pdg = -3 children = [18, 22]
# WARNING: multiple same-PDG children: parent = 14 pdg = 3 children = [16, 21]
# WARNING: multiple same-PDG children: parent = 13 pdg = -4 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 20 pdg = -1 children = [21, 27]
# WARNING: multiple same-PDG children: parent = 8 pdg = 5 children = [20, 21]
# WARNING: multiple same-PDG children: parent = 15 pdg = -3 children = [16, 29]
# WARNING: multiple same-PDG children: parent = 11 pdg = 5 children = [17, 23]
# WARNING: multiple same-PDG children: parent = 12 pdg = -1 children = [21, 28]
# WARNING: multiple same-PDG children: parent = 12 pdg = -5 children = [18, 19]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [12, 27]
# WARNING: multiple same-PDG children: parent = 13 pdg = 2 children = [21, 25]
# WARNING: multiple same-PDG children: parent = 16 pdg = 2 children = [18, 22]
# WARNING: multiple same-PDG children: parent = 11 pdg = 5 children = [22, 23]
# WARNING: multiple same-PDG children: parent = 13 pdg = -3 children = [22, 25]
# WARNING: multiple same-PDG children: parent = 14 pdg = -5 children = [20, 21]
# WARNING: multiple same-PDG children: parent = 7 pdg = 5 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 16 pdg = -3 children = [24, 25, 32]
# WARNING: multiple same-PDG children: parent = 8 pdg = -5 children = [18, 19]
# WARNING: multiple same-PDG children: parent = 17 pdg = -1 children = [18, 22]
# WARNING: multiple same-PDG children: parent = 13 pdg = -5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 13 pdg = -4 children = [21, 28]
# WARNING: multiple same-PDG children: parent = 13 pdg = -3 children = [19, 26]
# WARNING: multiple same-PDG children: parent = 7 pdg = 5 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 20 pdg = -3 children = [21, 33]
# WARNING: multiple same-PDG children: parent = 7 pdg = 5 children = [9, 19, 20]
# WARNING: multiple same-PDG children: parent = 13 pdg = 4 children = [21, 25]
# WARNING: multiple same-PDG children: parent = 15 pdg = -4 children = [21, 22]
# WARNING: multiple same-PDG children: parent = 14 pdg = -2 children = [20, 28]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [20, 21]
# WARNING: multiple same-PDG children: parent = 14 pdg = 2 children = [20, 36]
# WARNING: multiple same-PDG children: parent = 8 pdg = 5 children = [21, 22]
# WARNING: multiple same-PDG children: parent = 22 pdg = 2 children = [24, 26]
# WARNING: multiple same-PDG children: parent = 11 pdg = -5 children = [22, 23]
# WARNING: multiple same-PDG children: parent = 8 pdg = -5 children = [20, 21]
# WARNING: multiple same-PDG children: parent = 12 pdg = 1 children = [22, 29]
# WARNING: multiple same-PDG children: parent = 17 pdg = -4 children = [23, 26]
# WARNING: multiple same-PDG children: parent = 12 pdg = 1 children = [18, 29]
# WARNING: multiple same-PDG children: parent = 13 pdg = 3 children = [15, 24]
# WARNING: multiple same-PDG children: parent = 18 pdg = -3 children = [21, 23]
# WARNING: multiple same-PDG children: parent = 8 pdg = 5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 14 pdg = -3 children = [15, 21]
# WARNING: multiple same-PDG children: parent = 18 pdg = 2 children = [20, 22]
# WARNING: multiple same-PDG children: parent = 8 pdg = -5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 12 pdg = 1 children = [16, 19]
# WARNING: multiple same-PDG children: parent = 21 pdg = -3 children = [31, 33]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 9 pdg = -5 children = [21, 22]
# WARNING: multiple same-PDG children: parent = 12 pdg = 2 children = [16, 19]
# WARNING: multiple same-PDG children: parent = 19 pdg = -2 children = [24, 27]
# WARNING: multiple same-PDG children: parent = 8 pdg = 5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 15 pdg = -2 children = [16, 23]
# WARNING: multiple same-PDG children: parent = 15 pdg = 3 children = [17, 19]
# WARNING: multiple same-PDG children: parent = 12 pdg = 3 children = [20, 21]
# WARNING: multiple same-PDG children: parent = 14 pdg = -1 children = [16, 26]
# WARNING: multiple same-PDG children: parent = 11 pdg = 5 children = [25, 35]
# WARNING: multiple same-PDG children: parent = 16 pdg = 1 children = [21, 22]
# WARNING: multiple same-PDG children: parent = 13 pdg = -5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 15 pdg = 1 children = [17, 21]
# WARNING: multiple same-PDG children: parent = 16 pdg = -2 children = [17, 29]
# WARNING: multiple same-PDG children: parent = 20 pdg = 2 children = [23, 25]
# WARNING: multiple same-PDG children: parent = 14 pdg = 4 children = [16, 20]
# WARNING: multiple same-PDG children: parent = 8 pdg = 5 children = [10, 20]
# WARNING: multiple same-PDG children: parent = 15 pdg = 2 children = [17, 22]
# WARNING: multiple same-PDG children: parent = 11 pdg = 5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 8 pdg = -5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 10 pdg = 5 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 13 pdg = 5 children = [15, 26]
# WARNING: multiple same-PDG children: parent = 13 pdg = 2 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 15 pdg = 2 children = [19, 24]
# WARNING: multiple same-PDG children: parent = 14 pdg = 2 children = [16, 22]
# WARNING: multiple same-PDG children: parent = 14 pdg = -5 children = [16, 23]
# WARNING: multiple same-PDG children: parent = 11 pdg = -5 children = [13, 36]
# WARNING: multiple same-PDG children: parent = 14 pdg = -2 children = [19, 24]
# WARNING: multiple same-PDG children: parent = 13 pdg = 3 children = [15, 16]
# WARNING: multiple same-PDG children: parent = 9 pdg = -5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 15 pdg = -2 children = [20, 22]
# WARNING: multiple same-PDG children: parent = 8 pdg = 5 children = [20, 21]
# WARNING: multiple same-PDG children: parent = 15 pdg = -2 children = [16, 20]
# WARNING: multiple same-PDG children: parent = 7 pdg = 5 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 13 pdg = 1 children = [17, 22]
# WARNING: multiple same-PDG children: parent = 18 pdg = 4 children = [20, 21]
# WARNING: multiple same-PDG children: parent = 16 pdg = 1 children = [18, 23]
# WARNING: multiple same-PDG children: parent = 14 pdg = 3 children = [21, 27]
# WARNING: multiple same-PDG children: parent = 9 pdg = 5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 18 pdg = -2 children = [29, 40]
# WARNING: multiple same-PDG children: parent = 21 pdg = 4 children = [24, 25]
# WARNING: multiple same-PDG children: parent = 17 pdg = 4 children = [19, 28]
# WARNING: multiple same-PDG children: parent = 19 pdg = -2 children = [23, 30]
# WARNING: multiple same-PDG children: parent = 14 pdg = -3 children = [18, 25]
# WARNING: multiple same-PDG children: parent = 13 pdg = 4 children = [20, 23]
# WARNING: multiple same-PDG children: parent = 9 pdg = 5 children = [22, 23]
# WARNING: multiple same-PDG children: parent = 15 pdg = 2 children = [25, 29]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 10 pdg = 5 children = [22, 24]
# WARNING: multiple same-PDG children: parent = 15 pdg = 1 children = [17, 19]
# WARNING: multiple same-PDG children: parent = 15 pdg = 4 children = [18, 22]
# WARNING: multiple same-PDG children: parent = 9 pdg = 5 children = [20, 21]
# WARNING: multiple same-PDG children: parent = 13 pdg = -1 children = [19, 30]
# WARNING: multiple same-PDG children: parent = 14 pdg = -2 children = [20, 26]
# WARNING: multiple same-PDG children: parent = 11 pdg = -5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 16 pdg = 2 children = [24, 29]
# WARNING: multiple same-PDG children: parent = 12 pdg = -5 children = [22, 23]
# WARNING: multiple same-PDG children: parent = 12 pdg = -5 children = [18, 19]
# WARNING: multiple same-PDG children: parent = 14 pdg = 3 children = [16, 32]
# WARNING: multiple same-PDG children: parent = 12 pdg = -5 children = [18, 19]
# WARNING: multiple same-PDG children: parent = 13 pdg = 4 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 8 pdg = 5 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 10 pdg = 5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 16 pdg = 2 children = [21, 23]
# WARNING: multiple same-PDG children: parent = 12 pdg = 4 children = [19, 29]
# WARNING: multiple same-PDG children: parent = 15 pdg = -2 children = [16, 22]
# WARNING: multiple same-PDG children: parent = 18 pdg = -2 children = [23, 26]
# WARNING: multiple same-PDG children: parent = 14 pdg = -2 children = [23, 26]
# WARNING: multiple same-PDG children: parent = 12 pdg = 5 children = [23, 24]
# WARNING: multiple same-PDG children: parent = 13 pdg = 3 children = [21, 22]
# WARNING: multiple same-PDG children: parent = 8 pdg = 5 children = [21, 22]
# WARNING: multiple same-PDG children: parent = 18 pdg = 1 children = [20, 27]
# WARNING: multiple same-PDG children: parent = 14 pdg = 4 children = [20, 26]
# WARNING: multiple same-PDG children: parent = 7 pdg = 5 children = [15, 16]
# WARNING: multiple same-PDG children: parent = 13 pdg = -4 children = [15, 26]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 18 pdg = 3 children = [21, 25]
# WARNING: multiple same-PDG children: parent = 15 pdg = 5 children = [21, 22]
# WARNING: multiple same-PDG children: parent = 18 pdg = -2 children = [23, 29]
# WARNING: multiple same-PDG children: parent = 13 pdg = 3 children = [19, 21]
# WARNING: multiple same-PDG children: parent = 19 pdg = -3 children = [21, 25]
# WARNING: multiple same-PDG children: parent = 13 pdg = -3 children = [19, 21]
# WARNING: multiple same-PDG children: parent = 15 pdg = -1 children = [23, 29]
# WARNING: multiple same-PDG children: parent = 13 pdg = -3 children = [20, 26]
# WARNING: multiple same-PDG children: parent = 12 pdg = 2 children = [18, 21]
# WARNING: multiple same-PDG children: parent = 7 pdg = -5 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 20 pdg = -1 children = [22, 26]
# WARNING: multiple same-PDG children: parent = 11 pdg = -5 children = [12, 20]
# WARNING: multiple same-PDG children: parent = 7 pdg = -5 children = [9, 27]
# WARNING: multiple same-PDG children: parent = 16 pdg = -1 children = [18, 21]
# WARNING: multiple same-PDG children: parent = 9 pdg = 5 children = [15, 21]
# WARNING: multiple same-PDG children: parent = 8 pdg = 5 children = [21, 22]
# WARNING: multiple same-PDG children: parent = 7 pdg = 5 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 10 pdg = 5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 12 pdg = 2 children = [16, 19]
# WARNING: multiple same-PDG children: parent = 14 pdg = -2 children = [23, 28]
# WARNING: multiple same-PDG children: parent = 13 pdg = -5 children = [21, 22]
# WARNING: multiple same-PDG children: parent = 7 pdg = 5 children = [9, 34]
# WARNING: multiple same-PDG children: parent = 13 pdg = -3 children = [19, 21]
# WARNING: multiple same-PDG children: parent = 8 pdg = -5 children = [18, 19]
# WARNING: multiple same-PDG children: parent = 11 pdg = 2 children = [15, 18]
# WARNING: multiple same-PDG children: parent = 14 pdg = -1 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 15 pdg = -2 children = [19, 26]
# WARNING: multiple same-PDG children: parent = 13 pdg = -1 children = [18, 20]
# WARNING: multiple same-PDG children: parent = 7 pdg = -5 children = [18, 19]
# WARNING: multiple same-PDG children: parent = 15 pdg = 1 children = [22, 24]
# WARNING: multiple same-PDG children: parent = 19 pdg = -3 children = [20, 28]
# WARNING: multiple same-PDG children: parent = 11 pdg = 5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 14 pdg = -1 children = [18, 20]
# WARNING: multiple same-PDG children: parent = 11 pdg = 4 children = [15, 19]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 12 pdg = -5 children = [21, 22]
# WARNING: multiple same-PDG children: parent = 15 pdg = 3 children = [19, 26]
# WARNING: multiple same-PDG children: parent = 18 pdg = -2 children = [23, 26]
# WARNING: multiple same-PDG children: parent = 12 pdg = 3 children = [21, 24]
# WARNING: multiple same-PDG children: parent = 18 pdg = -2 children = [19, 25]
# WARNING: multiple same-PDG children: parent = 11 pdg = -5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 15 pdg = 1 children = [17, 19]
# WARNING: multiple same-PDG children: parent = 12 pdg = -5 children = [21, 22]
# WARNING: multiple same-PDG children: parent = 19 pdg = 3 children = [23, 30]
# WARNING: multiple same-PDG children: parent = 14 pdg = -2 children = [15, 25]
# WARNING: multiple same-PDG children: parent = 10 pdg = 5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 17 pdg = -2 children = [21, 25]
# WARNING: multiple same-PDG children: parent = 20 pdg = 1 children = [24, 26]
# WARNING: multiple same-PDG children: parent = 13 pdg = -1 children = [17, 21]
# WARNING: multiple same-PDG children: parent = 12 pdg = 1 children = [17, 21]
# WARNING: multiple same-PDG children: parent = 22 pdg = 2 children = [26, 27]
# WARNING: multiple same-PDG children: parent = 11 pdg = -5 children = [18, 19]
# WARNING: multiple same-PDG children: parent = 7 pdg = 5 children = [16, 17, 18]
# WARNING: multiple same-PDG children: parent = 13 pdg = -5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 9 pdg = 5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 14 pdg = -4 children = [17, 24]
# WARNING: multiple same-PDG children: parent = 19 pdg = 1 children = [21, 23]
# WARNING: multiple same-PDG children: parent = 13 pdg = -2 children = [14, 32]
# WARNING: multiple same-PDG children: parent = 20 pdg = 2 children = [24, 30]
# WARNING: multiple same-PDG children: parent = 17 pdg = 1 children = [24, 28]
# WARNING: multiple same-PDG children: parent = 10 pdg = 5 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 16 pdg = -3 children = [17, 25]
# WARNING: multiple same-PDG children: parent = 11 pdg = 3 children = [15, 16]
# WARNING: multiple same-PDG children: parent = 9 pdg = 5 children = [21, 22]
# WARNING: multiple same-PDG children: parent = 11 pdg = 3 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 14 pdg = -3 children = [18, 24]
# WARNING: multiple same-PDG children: parent = 16 pdg = -4 children = [27, 32]
# WARNING: multiple same-PDG children: parent = 14 pdg = 3 children = [21, 23]
# WARNING: multiple same-PDG children: parent = 13 pdg = 1 children = [17, 22]
# WARNING: multiple same-PDG children: parent = 13 pdg = 3 children = [18, 19]
# WARNING: multiple same-PDG children: parent = 14 pdg = -2 children = [15, 21]
# WARNING: multiple same-PDG children: parent = 8 pdg = 5 children = [16, 18]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 14 pdg = 2 children = [18, 25]
# WARNING: multiple same-PDG children: parent = 12 pdg = 4 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 17 pdg = 3 children = [24, 31]
# WARNING: multiple same-PDG children: parent = 16 pdg = -4 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 18 pdg = -1 children = [19, 24]
# WARNING: multiple same-PDG children: parent = 13 pdg = 2 children = [17, 20]
# WARNING: multiple same-PDG children: parent = 7 pdg = 5 children = [15, 16]
# WARNING: multiple same-PDG children: parent = 15 pdg = 1 children = [19, 22]
# WARNING: multiple same-PDG children: parent = 14 pdg = 1 children = [16, 19]
# WARNING: multiple same-PDG children: parent = 21 pdg = 1 children = [25, 40]
# WARNING: multiple same-PDG children: parent = 13 pdg = 1 children = [18, 19]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [12, 21]
# WARNING: multiple same-PDG children: parent = 20 pdg = 1 children = [24, 26]
# WARNING: multiple same-PDG children: parent = 9 pdg = 5 children = [20, 24]
# WARNING: multiple same-PDG children: parent = 11 pdg = 3 children = [18, 27]
# WARNING: multiple same-PDG children: parent = 12 pdg = 4 children = [19, 23]
# WARNING: multiple same-PDG children: parent = 14 pdg = -3 children = [27, 33]
# WARNING: multiple same-PDG children: parent = 17 pdg = 1 children = [19, 22]
# WARNING: multiple same-PDG children: parent = 19 pdg = -4 children = [21, 22]
# WARNING: multiple same-PDG children: parent = 9 pdg = -5 children = [20, 21]
# WARNING: multiple same-PDG children: parent = 11 pdg = -5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 12 pdg = 3 children = [16, 26]
# WARNING: multiple same-PDG children: parent = 12 pdg = 1 children = [14, 19]
# WARNING: multiple same-PDG children: parent = 7 pdg = 5 children = [20, 21]
# WARNING: multiple same-PDG children: parent = 12 pdg = 5 children = [18, 19]
# WARNING: multiple same-PDG children: parent = 13 pdg = -3 children = [16, 21]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [20, 21]
# WARNING: multiple same-PDG children: parent = 17 pdg = 4 children = [19, 21]
# WARNING: multiple same-PDG children: parent = 12 pdg = 2 children = [17, 27]
# WARNING: multiple same-PDG children: parent = 13 pdg = 1 children = [15, 19]
# WARNING: multiple same-PDG children: parent = 16 pdg = 2 children = [18, 19]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [16, 17, 18]
# WARNING: multiple same-PDG children: parent = 14 pdg = 3 children = [18, 32]
# WARNING: multiple same-PDG children: parent = 12 pdg = -5 children = [21, 22]
# WARNING: multiple same-PDG children: parent = 11 pdg = 5 children = [20, 21]
# WARNING: multiple same-PDG children: parent = 12 pdg = 3 children = [16, 21]
# WARNING: multiple same-PDG children: parent = 12 pdg = -5 children = [21, 22]
# WARNING: multiple same-PDG children: parent = 7 pdg = 5 children = [8, 23]
# WARNING: multiple same-PDG children: parent = 15 pdg = -2 children = [26, 29]
# WARNING: multiple same-PDG children: parent = 10 pdg = -5 children = [11, 21]
# WARNING: multiple same-PDG children: parent = 8 pdg = 5 children = [21, 22]
# WARNING: multiple same-PDG children: parent = 16 pdg = -2 children = [20, 28]
# WARNING: multiple same-PDG children: parent = 15 pdg = 1 children = [19, 21]
# WARNING: multiple same-PDG children: parent = 10 pdg = 5 children = [19, 20]
# WARNING: multiple same-PDG children: parent = 18 pdg = 1 children = [21, 22]
# WARNING: multiple same-PDG children: parent = 18 pdg = -4 children = [19, 38]
# WARNING: multiple same-PDG children: parent = 7 pdg = 5 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 8 pdg = -5 children = [22, 23]
# WARNING: multiple same-PDG children: parent = 8 pdg = -5 children = [16, 17]
# WARNING: multiple same-PDG children: parent = 23 pdg = 3 children = [26, 29]
# WARNING: multiple same-PDG children: parent = 15 pdg = -1 children = [23, 30]
# WARNING: multiple same-PDG children: parent = 14 pdg = -4 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 22 pdg = 4 children = [23, 24]
# WARNING: multiple same-PDG children: parent = 19 pdg = 1 children = [21, 25]
# WARNING: multiple same-PDG children: parent = 10 pdg = 5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 13 pdg = -1 children = [24, 26]
# WARNING: multiple same-PDG children: parent = 8 pdg = 5 children = [17, 18]
# WARNING: multiple same-PDG children: parent = 10 pdg = 5 children = [22, 32]
# WARNING: multiple same-PDG children: parent = 14 pdg = -4 children = [20, 21]
# WARNING: multiple same-PDG children: parent = 9 pdg = -5 children = [22, 23]
# WARNING: multiple same-PDG children: parent = 14 pdg = 3 children = [22, 23]
# ...
# <div id="root_plot_1785523191469" style="width: 800px; height: 600px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1785523191469(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-18.7500013969839,"fY1":-0.0538881491041294,"fX2":168.750001396984,"fY2":0.484993309817325,"fXtoAbsPixelk":79.6000047445299,"fXtoPixelk":79.6000047445299,"fXtoPixel":4.24533327007293,"fYtoAbsPixelk":514.799996590614,"fYtoPixelk":514.799996590614,"fYtoPixel":-1061.45793389298,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":796,"fVtoAbsPixelk":572,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-18.7500013969839,"fPixeltoXk":-18.7500013969839,"fPixeltoX":0.235552767329105,"fAbsPixeltoYk":0.484993309817325,"fPixeltoYk":-0.0538881491041294,"fPixeltoY":-9.42100452659886e-4,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":150,"fUymax":0.431105160713196,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":true,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c_Dn_leptonic","fTitle":"c_Dn_leptonic","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":15,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":796,"fCh":572,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fClassName":"","fObjectName":"","fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,3 ...
# <div id="root_plot_1785523191472" style="width: 800px; height: 600px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1785523191472(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-18.7500013969839,"fY1":-0.0533370853094075,"fX2":168.750001396984,"fY2":0.480033735993287,"fXtoAbsPixelk":79.6000047445299,"fXtoPixelk":79.6000047445299,"fXtoPixel":4.24533327007293,"fYtoAbsPixelk":514.799996590614,"fYtoPixelk":514.799996590614,"fYtoPixel":-1072.42461933511,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":796,"fVtoAbsPixelk":572,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-18.7500013969839,"fPixeltoXk":-18.7500013969839,"fPixeltoX":0.235552767329105,"fAbsPixeltoYk":0.480033735993287,"fPixeltoYk":-0.0533370853094075,"fPixeltoY":-9.32466470808907e-4,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":150,"fUymax":0.42669665068388,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":true,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c_Dn_hadronic","fTitle":"c_Dn_hadronic","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":15,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":796,"fCh":572,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fClassName":"","fObjectName":"","fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33 ...
# <div id="root_plot_1785523191474" style="width: 800px; height: 600px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1785523191474(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-62.5000046566132,"fY1":-0.0192932879025703,"fX2":562.500004656613,"fY2":0.173639579623438,"fXtoAbsPixelk":79.60000474453,"fXtoPixelk":79.60000474453,"fXtoPixel":1.27359998102188,"fYtoAbsPixelk":514.799996590614,"fYtoPixelk":514.799996590614,"fYtoPixel":-2964.761822777,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":796,"fVtoAbsPixelk":572,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-62.5000046566132,"fPixeltoXk":-62.5000046566132,"fPixeltoX":0.785175891097018,"fAbsPixeltoYk":0.173639579623438,"fPixeltoYk":-0.0192932879025703,"fPixeltoY":-3.37295222947566e-4,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":500,"fUymax":0.154346291720867,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":true,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c_Mbhj","fTitle":"c_Mbhj","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":15,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":796,"fCh":572,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fClassName":"","fObjectName":"","fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,251; ...
